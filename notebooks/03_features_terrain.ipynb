# %% [markdown]
# # Part 3 — Terrain features
#
# **Source:** `USGS/SRTMGL1_003` + `WWF/HydroSHEDS/15ACC`
#
# **Output:** `feat_terrain` (250 m). **DoD:** slope 0–~45°, no NaN holes.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../src'))
import ee, geemap
import utils, features
project = utils.init()
print('EE initialized; project =', project)

# %%
aoi = utils.load_aoi(project)
print('AOI area (km^2):', round(aoi.area(1000).divide(1e6).getInfo(), 1))

# %% [markdown]
# ### Build the feature image

# %%
img = features.terrain_features(aoi)
print('bands:', img.bandNames().getInfo())

# %% [markdown]
# ### DoD sanity — per-band min/mean/max

# %%
utils.range_report(img, aoi)

# %% [markdown]
# ### Quick look

# %%
Map = geemap.Map()
Map.centerObject(aoi, 7)
Map.addLayer(img.select('terr_slope'), {'min': 0, 'max': 20, 'palette': ['green','yellow','red']}, 'terr_slope')
Map.addLayer(aoi, {}, 'AOI', False)
Map

# %% [markdown]
# ### Export to EE asset

# %%
utils.ensure_folder(project)
task = utils.export_image(img, project, 'feat_terrain', aoi)
print('export', task.status()['description'], '->', task.status()['state'])
